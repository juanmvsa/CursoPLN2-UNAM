# %%
! pip install -U spacy
! python -m spacy download es_dep_news_trf
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (3.3.0)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.10.0.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.8.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.4.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /usr/local/lib/python3.7/dist-packages (from spacy) (8.0.15)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (21.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.6.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.9.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.64.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy) (3.0.8)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy) (8.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy) (2.0.1)
# Collecting es-dep-news-trf==3.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_dep_news_trf-3.3.0/es_dep_news_trf-3.3.0-py3-none-any.whl (410.2 MB)
#      |████████████████████████████████| 410.2 MB 11 kB/s
# Requirement already satisfied: spacy-transformers<1.2.0,>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from es-dep-news-trf==3.3.0) (1.1.5)
# Requirement already satisfied: spacy<3.4.0,>=3.3.0.dev0 in /usr/local/lib/python3.7/dist-packages (from es-dep-news-trf==3.3.0) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (3.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (2.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (0.4.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (1.8.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (0.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (3.0.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (2.23.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (2.11.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (0.9.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (1.0.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (2.0.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (21.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (1.21.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (4.64.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (57.4.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (3.3.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (8.0.15)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (3.10.0.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (1.0.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (0.4.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (3.0.8)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (5.2.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (3.0.4)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (1.11.0+cu113)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (0.8.5)
# Requirement already satisfied: transformers<4.18.0,>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (4.17.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<4.18.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (2019.12.20)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers<4.18.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<4.18.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (3.6.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers<4.18.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (0.0.50)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers<4.18.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (0.5.1)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers<4.18.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (0.12.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<4.18.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (4.11.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (8.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (2.0.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<4.18.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<4.18.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (1.15.0)
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_dep_news_trf')

# %%
import spacy

import es_dep_news_trf

nlp = es_dep_news_trf.load()

# %% [markdown]
# # Retomando el ejercicio de las sesiones 2 y 3

# %% [markdown]
# Paso 1: Definir la ruta de Drive en la cual esta guardado nuestro archivo.
#
# Paso 2: Cargar esos datos en una variable llamada `datos`. En este caso el comando `sep="\t"` es necesario cuando nuestros datos están en formato `.tsv`.
#
# Paso 3: Imprimir la variable `datos`.

# %%
import pandas as pd

ruta = '.../datos_deteccion_sexismo.tsv'

datos = pd.read_csv(ruta, sep="\t")
datos
# Out:
#       test_case    id   source language  \
# 0     EXIST2021     1  twitter       en
# 1     EXIST2021     2  twitter       en
# 2     EXIST2021     3  twitter       en
# 3     EXIST2021     4  twitter       en
# 4     EXIST2021     5  twitter       en
# ...         ...   ...      ...      ...
# 6972  EXIST2021  6973  twitter       es
# 6973  EXIST2021  6974  twitter       es
# 6974  EXIST2021  6975  twitter       es
# 6975  EXIST2021  6976  twitter       es
# 6976  EXIST2021  6977  twitter       es
#
#                                                    text       task1  \
# 0     She calls herself "anti-feminazi" how about sh...      sexist
# 1     Now, back to these women, the brave and the be...  non-sexist
# 2     @CurvyBandida @Xalynne_B Wow, your skirt is ve...      sexist
# 3     @AurelieGuiboud Incredible!  Beautiful!But I l...  non-sexist
# 4     i find it extremely hard to believe that kelly...  non-sexist
# ...                                                 ...         ...
# 6972  Estamos igual sin pareja, pero puedes besar a ...  non-sexist
# 6973                          2020 hijo de re mil putas  non-sexist
# 6974  SEGURAMENTE ESTA CHICA NO COBRA EL DINERO QUE ...  non-sexist
# 6975     @safetyaitana mi madre dice q va fea y i agree      sexist
# 6976  ¿En vuestras casas también tenéis esa tradició...      sexist
#
#                        task2
# 0     ideological-inequality
# 1                 non-sexist
# 2            objectification
# 3                 non-sexist
# 4                 non-sexist
# ...                      ...
# 6972              non-sexist
# 6973              non-sexist
# 6974              non-sexist
# 6975         objectification
# 6976  stereotyping-dominance
#
# [6977 rows x 7 columns]

# %%
datos.drop(['test_case', 'id', 'source', 'task1', 'task2'], axis=1, inplace=True)
datos
# Out:
#      language                                               text
# 0          en  She calls herself "anti-feminazi" how about sh...
# 1          en  Now, back to these women, the brave and the be...
# 2          en  @CurvyBandida @Xalynne_B Wow, your skirt is ve...
# 3          en  @AurelieGuiboud Incredible!  Beautiful!But I l...
# 4          en  i find it extremely hard to believe that kelly...
# ...       ...                                                ...
# 6972       es  Estamos igual sin pareja, pero puedes besar a ...
# 6973       es                          2020 hijo de re mil putas
# 6974       es  SEGURAMENTE ESTA CHICA NO COBRA EL DINERO QUE ...
# 6975       es     @safetyaitana mi madre dice q va fea y i agree
# 6976       es  ¿En vuestras casas también tenéis esa tradició...
#
# [6977 rows x 2 columns]

# %%
datos = datos[datos['language'] != 'en']
datos
# Out:
#      language                                               text
# 3436       es  Nadie te va a tratar tan bien como un hombre q...
# 3437       es  @lindagisela74 Que rica putita obediente, afor...
# 3438       es  @BicireporteraDF Yo lo hice a los 18 años por ...
# 3439       es  las cosas q sueño son indicios de que yo enrea...
# 3440       es  Pero a la niña le gustó desde que lo vió, así ...
# ...       ...                                                ...
# 6972       es  Estamos igual sin pareja, pero puedes besar a ...
# 6973       es                          2020 hijo de re mil putas
# 6974       es  SEGURAMENTE ESTA CHICA NO COBRA EL DINERO QUE ...
# 6975       es     @safetyaitana mi madre dice q va fea y i agree
# 6976       es  ¿En vuestras casas también tenéis esa tradició...
#
# [3541 rows x 2 columns]

# %%
tuits = []

for tuit in datos['text']:
  tuits.append(str(tuit))

tuits
# Out:
# ['Nadie te va a tratar tan bien como un hombre que te lo quiere meter por primera vez.',
#  '@lindagisela74 Que rica putita obediente, afortunado tu marido de tener una mujer como tú, saludos',
#  '@BicireporteraDF Yo lo hice a los 18 años por la carretera libre a Veracruz y ahora hay más carreteras veras que si puedes mujer',
#  'las cosas q sueño son indicios de que yo enrealidad soy una lesbiana reprimida, no tengo ninguna duda d esto',
#  'Pero a la niña le gustó desde que lo vió, así que me le dije, hola bien y tú? Ese día sólo podía ver un hombre guapo, moreno (como me gustan) con una barba que rodeaba su boca tan perfecta y unos ojazos que wow. Hasta las manos le vi ajjaja por que si me fijo en eso',
#  '@Agus_Martinez58 @AlmeidaPP_ Faltar al respeto nunca ha sido la solución a nada. Un poco de clase y elegancia, hombre. Dice muy poco de usted como periodista si necesita recurrir al insulto fácil.',
#  'LA ALCALDESA CLAUDIA LOPEZ Y DEMAS ALCALDESPRETENDEN METER POR LA SEPTIMA LO QUE NO CABELO QUE NO CABE NO CABELA SEPTIMA DESDE LA CALLE 32 A LA CALLE 100 ES MUY ESTRECHA HAY QUE HACER UNA VIA EXPRESASUBTERRANEA O AEREA https://t.co/xY9smufSdS https://t.co/rhuvSXhypu',
#  '@6Asca @ladycristall Sigues lloriqueando, no me des la brasa nenaza',
#  'Y para nada estoy diciendo esto desde un sitio de victimismo; al contrario, ser empático con las causas de personas como tú te empodera a ti y a quienes te rodean, así que antes de decir que “no hablen por ti esos grupos”...',
#  'Que atractiva es la seguridad.',
#  'Perdonar lo no sólo es posible, es absolutamente necesario. Estoy harta de las boludas que acusan de todos los males de la humanidad a los hombres. Muerte al feminismo',
#  'El odio que te tengo nunca se me va a quitar pinché lagartona',
#  'Al momento de sentarme a estudiar todo me parece más interesante y divertido, desde pintarme las uñas hasta fregar, limpiar o simplemente mirar para afuera sin hacer nada conchalalora',
#  'Cuando pasan delante tuya todos los ciriales de La Mortaja en una calle estrecha. https://t.co/N19KHrYztB',
#  'En los últimos años, Rusia ha sido escenario de varios de los juicios por asesinatos en serie con más víctimas en el mundo, incluyendo un caso con 78 víctimas, y otro con 48. https://t.co/gU0tPutbdc',
#  '@v1ctoriasensual ummmm q serradita amor se mira q eres muy estrecha',
#  '¡A ti, mujer luchadora! (Jorge Acuña)"Mujer trabajadora, rebelde y soñadoraLlena de defectos y grandes virtudesLlena de amor y comprensiónLlena de coherencia y firme convicciónDe un profundo compromiso con la revolución"#DiciembreVictorioso',
#  'NARANJA QUE TE QUIERO NARANJA https://t.co/yZyNbQ3Lt9 Bueno, yo siempre he dicho que Claudia es una mujer atractiva.. pero el maese Magú se empecina en hacer unos monos re gruesos..Verde que te quiero, verde..Era el refrán.. no?En fin, lindo cartón..Va.. putitos con tos..',
#  '@CarlosGarcia09 Noche golfa?',
#  '"Cuando las mujeres han podido comprar sus propias prendas deportivas en alguna tienda deben conformarse con la talla masculina más chica, porque la oferta para mujeres no existe"; un texto de  texto de @glaseadodementa https://t.co/yWSYGLX6GP',
#  'Ataraxia:Me evado bajo la membrana rígidadel agua frígida de la que emanadichosa psique que desmiembra mi calmacada mañana y madrugada,y la envuelve en cálidas sábanascreadas en las costurasde tus palabras a mi alma.',
#  'Busco mujer que viva en Torrevieja o cerca de Alicante para follar',
#  'Este Néstor Humberto es la peor escoria https://t.co/JzUiXPFo3m',
#  'Chicas me había olvidado l letra de this is what it takes la puta madre',
#  'Gracias por apoyar a las mujeres q más lo necesitan https://t.co/bq2I4IDIkl',
#  '@flormolina30 Siempre frida nunca frigida! ♥',
#  'busco mujer q quiera ser felizrequisistos para estar con santi dumrauf:*edad:16-30*estatura:1,60-1.79*tetas y culo me da igual*q se lave los dientes*q sea de sagitario libra acuario aries o virgo (mm)*q le guste follar duro y salvaje y también tierno y mimoso.',
#  '[Pedicabo ego vos et irrumabo] es una frase latina muy popular. Hay traducciones muy pasionales, así como hay otras más cercanas al texto latino. "Paedico" se traduce como sodomizar e "irrumo" se traduce como insertar violentamente un pene dentro de la boca. https://t.co/soZy7uWf2N',
#  'Además no entiendo, porque se legalice el aborto no van a salir todas las mujeres a abortar, todo lo contrario, en los países que es legal se aborta menos, entonces deberian apoyar la legalización, aparte es sencillo, quien no quiera abortar que no aborte, no te obligan',
#  'Es impresionante como algo tan fantástico como el satisfyer llega a convertirse en un aparato de tortura en las manos de un hombre oye... Ni eso hacen bien.',
#  '@elenaaabon @Conde_Macula Es que dentro de poco, vamos a tener que castrarnos, por ser solamente hombres... Que hay mucho hijo de puta violador, maltratador etc... Lo sabemos todos, pero se están pasando con el feminismo radical',
#  'Si el hombre siempre ha sido el ser superior y dominante, y la mujer la "sumisa"... ¿Cómo se equilibra esto buscando la igualdad y que ninguno sea superior a otro? Pues protegiendo a la mujer, no vas a proteger al hombre...',
#  '@ElHuffPost @eltelevisero Quiso censurar. Monasterio valiente como pocas.La verdadera mujer empoderada!',
#  'qué tan mierda de persona tenes que ser para desearle eso a 4 mujeres que nunca te hicieron nada? y aún así no las quieras o no las aguantes NUNCA deberían hablar así de ellas ni de ninguna otra mujerme importa un choto si lo decía posta o para joder, se van a la mierda ls odio',
#  '@lebiram34980787 @asifuevalencia Jesús Vázquez  .tú eres noble y dices lo que tú corazón siente Pantoja se merece esas palabras',
#  '@SobrinoV_Edu Esta muerto de miedo como tu club, que en un campo de juego fue vergonzoso y bien merecido el descenso, ahora es de hombre asumirlo y no estar de llorón con algunos periodistas para meter presión para que se mantengan son tan impresentable como Lozano.',
#  'Si hoy no llevas corsé puede que sea gracias a   ella, y si eres mujer y has estudiado en universidad española, en parte también...#MujeresInvisibles#Pioneras @cero Dolors Aleu, la ginecóloga rebelde contra la opresión del corsé https://t.co/leBisfxyck vía @agencia_sinc',
#  'Esta GENERACIÓN LAGARTONA CONSERVADORA ya no debe tener espacio en el pais. Ya pasaron más de 30 anös y siguen con pensamientos cojudos, retrógrados, y explotadores del régimen laboral. Terminemos el 2021 con la #GeneraciónASILO y enviémoslos a su casa for good!@CoordinadoraRep https://t.co/t5vjjz86tI',
#  '@FBuenAbad Respeto a la vida, a la dignidad del hombre (incluido la mujer) y libre desempeño de la personalidad. Eso es el chavismo para mi. Creo que el socialismo es solo una doctrina de organización social basados en principios científicos y morales con fines de convivencia armonica!',
#  '@andres_trasado @KyriosCV Qué es majors? Conozco majorettes. Por qué vas a criticar majorettes? #metoo',
#  '@gmpsantander Las mujeres sordas, con baja audición, no verbales o sordociegas víctimas de maltrato pueden llamar al 016 con 900.116.016, SVisual, ALBA, Telesor, ATENPRO y la app PorMí. Al 112 con la app 112Accesible. Al 091 y 062 con SVIsual y app AlertCops. #ViolenciaMachista #Accesibilidad',
#  'DEJO QUE SU MUJER SE FUERA TODO EL FIN DE SEMANA A FOLLAR CON SU EX https://t.co/5Ug61DOLZP',
#  '@IreneMontero Díselo a tu marido, que además de soñar con azotar mujeres le gustaba mucho Maradona.',
#  '@EstefaniaVeloz Que onda con estas Fakeministas, por esto ahora van a querer ir a pintar, destruir y a golpear a las policías??? Porfavor no nos discrimine porque no todos los hombres somos iguales.',
#  '@Paolita_ocean @fabiss84 Yo no tengo estudio pero si leo (A los) hombres creo que es = a (todos los) si no es así alguien que me explique la diferencia por favor.',
#  '#ElJuegoDeChileEnTVN - Ahora comienza “Despistados”, cuando la competencia continúa muy estrecha.  Sigue la señal en vivo https://t.co/6klJxtqFSM https://t.co/pZgu9tRHcA',
#  '@CesarAlvCa Creo que para evitar estas cosas, hombres y mujeres deberían pasar pruebas de reducciones ante personas violentas, y el/la que no las pase prohibido patrullar en la calle, sin más.Porque esto puede salir así o puede ser que al compañero incluso le cosan a puñaladas, o algo peor.',
#  'Soy una guarra',
#  'Como culé, estoy hasta la polla de leer comentarios así de llorones. Defender el estilo Barça no significa tener que atacar a todos los equipos que defienden, significa querer que el Barça obligue a todos a jugar así para frenarlo. El 2-8 nos lo metieron poniendo el autobús? https://t.co/Vf9lIqRa6k',
#  '#ChaoFrenteAmplio y de paso chao partido comunista , son la escoria del mundo !!',
#  '@ParejitaVeracr2 Amigo está buenísima tu mujer!! Me encantó!! Que buen par de tetas!!! Simplemente perfecta!!',
#  '@MexKrispyKreme lleve mi dona a la sucursal y las señoritas igual de ofendidas por la promoción de 70 pesos una dona y no me pueden hacer la devolución y dejé abandonada la dona más cara que han vendido.',
#  '@WharfRat_DE Eso es manspreading ¿no?',
#  '@luchadisidente @Txikiteros Y a azotar a mujeres hasta que sangren',
#  '#Notallmen: me siento mal de no haber podido satisfacerte...Yo: Wey!... No te des tanta importancia se necesita muchísimo más que tú pito para que yo esté SATISTECHA! #Lunes #FelizInicioDeSemana',
#  'MENSAJE DE EMPODERAMIENTO Y ACCION HOY CON LEGENDARIO ALEXIS ADAME DIC 7 https://t.co/mjb5wA3GMb vía @YouTube',
#  'El ser humano remplazó la religión con la política.Ya no cree en Dios pero se deja sodomizar de politiqueros ansiosos de poder.',
#  '@thiagowo_ buen dia como estas me pareces una doncella digna de cuento de hadas y querria hacerte una propuesta indecente, invitarte a mi humilde hogar en el horario que mejor se acomode a ti. saludos cordiales bella damisela que ganas de comerte la concha puta',
#  '@_xCain_ — Y ahí estaba, justo lo que quería escuchar, cada una de esas palabras ¿como conseguía comprenderle tan bien sin necesidad de ponerlo todo patas arriba como siempre le pasaba?... Se notaba a millas cuando un hombre ha sido curtido por el tiempo, la madurez y la sensatez. (+)',
#  '@MaxKaiser75 No mezclen un equipo Cona escoria de morena también',
#  'Así Claudio Fermín "gane" como fraudediputado, en su finitud será un perdedor y está dentro de los políticos menos dignos. Lo malo para Venezuela es que la carrera de los políticos termina con su muerte y hasta sus últimos días pueden fregar a los ciudadanos.',
#  'Parte de la idiosincrasia es pensar que todas las mujeres son unas santas, que cuando hacen algo mal, fue por la culpa de un hombre o fue orillada a realizarlo. Cinismo',
#  'Niño, deja a mi perro dormir',
#  'Esteban Echeverría: un asesino al volante atropelló a una mujer que circulaba en bicicleta. El conductor escapó sin asistirla. Iris esta viva de milagroNOTICIAS 1 MINUTO Radio   #1LAGENTESIEMPRE https://t.co/JlPcajPx4T https://t.co/RdFdDs6Svh',
#  '@aracelibs @Anaro74 @malusita76 #MeToo ;) pero nos van a hacer alcoholicos =(',
#  '@Laucaba Creo que algún abogado de Derechos Humanos debe interponer una demanda, por el daño que puede causar su video a las jóvenes y mujeres de este país y del mundo por difundir un video dañino a la salud pública mundial @AztecaNoticias',
#  '@JosLuis70921676 La perspectiva d la salud es importante pero también hay que saber que hay que cogerla con pinzas por años de androcentrismo. No dejarla de aplicar, sino cambiarla donde no hace ningún bien https://t.co/WG4V09XxEK comparto artículo que reflexiona sobre esta falta en p. de salud',
#  '@carlosmcnamara @PabloWende @infobae Pero esto no tiene correlacion con el plazo fijo uva. Si es verdad esta reprimida la inflacion, el UVA te refleja la inflacion actual; cuando la inflacion deje de estar reprimida y se dispare se va a ver reflejado en el indice UVA',
#  'Esa jovencita tiene tanto que enseñarme. Mas que a mi edad he sido muy reprimida. Debo soltarme más a los verdaderos placeres de la vida https://t.co/hzYDBb0Pxo',
#  '@todosemosETB @DinaBousselham De quiénes hablas??Hice un tuit hacia una persona pública.Te metistes en medio con el único argumento para defenderla de el insulto hacia mí.Y ahora hablas de conspiraciones?Soy una mujer libre que expreso mi opinión y punto.',
#  'Tanto vas a mirar gorda lechón??',
#  'A kokichi se le subió la fama #kokichicanceled2020',
#  '@Mar18blink @angelisapinks @livexlive @BLACKPINK #HYLTWORLDWIDESTREAMING por favor hagan stream a HYLT, estamos muy cerca de perder el puesto número 1 del mv mas visto del 2020, por las chicas ): #HYLTWORLDWIDESTREAMING',
#  'se lo merece todo  https://t.co/YGhj9s9V9s',
#  'la chica',
#  '@mariamadzam1 Esta mujer, es buena tipa!',
#  'El Aborto no es reponsabilidad exclusiva de la mujer. La culpa se comparte mitad mujeres y mitad hombres el feto es 50%Espermatozoide y 50% Ovulo. No lo olviden y si lo hacen sean responsables tomen las pastillas y usen condon para evitar llamar a su hijo "Problema" en el futuro.',
#  '@Hebesac23 @matuk De ninguna manera, ninguna mujer debe aceptar que las agredan. Pero los supuestos defensores de mujeres deberían serlo siempre, no solo con algunas. O más que defensores de mujeres son defensores de una ideología?',
#  'paki reprimida',
#  'Sra Corrupta, le recomiendo no perder su tiempo y vaya a realizarle otra entrevista a Sagastegui y dígale que aunque esté encargado de la Presidencia, tiene la responsabilidad de conducir al país y que el TC no es su mamá, donde acude cada vez que el Congreso decide fregar. https://t.co/Py1j2Y9mkg',
#  '@LuciaAlvites  Si ud quiere cortese un brazo, una pierna, la cabeza,corte sus trompas de falopioQuiénes están esclavizadas? Ud solo usa falacias Y mentiras.Supuestamente defiende a las mujeres, pero promueve su muerte desde el vientre materno, también de varones xq promueve el odio',
#  '@lunaysol01234 @DINGO40378066 @basi2021 @KarenRi51542403 @te_corrijo_ @ReyesFdez @IrinaMoncherie @RayDonovan8812 @leveltgn @CarlosSinMas4 @francandeira @Asquidistancia Para fascistas el #chepas y su camarilla, que están todo el día escupiendo odio por la boca, llamando a romper mobiliario urbano, deseando azotar mujeres hasta sangrar o salir a la calle a cazar gente que no piensa igual. Si eso no es fascismo el fascismo no existe.',
#  '@c4jimenez @TuAlcaldiaGAM @SSC_CDMX @PDI_FGJCDMX @FiscaliaCDMX A ver cuántos se tardan las feminazis en venir a fregar con su cantaleta de PoR EsO dEBemOs MTarLos En EL BiEntre Avorto Legal Y gratiS Serà Ley',
#  'Yo creo que mi madre en verdad es una bollera reprimida o algo si no no me lo explico',
#  '@FRA305MJU86 @SUSANAMMLPQTP @Agoslagos19 @MascioNorberto Y como combatir los embarazos no deseados?? Ya se!! Vasectomía para TODOS los hombres, aunque no lo quieran.',
#  'La lucha de clases se subroga en la lucha de castas; que no se diga que no se ha avisadoLa ciudadanía en igualdad de derechos sale tan rápido como entró; justo para deslegitimar reivindicaciones y descargar malas conciencias, la sustituye la igualdad de derechos entre iguales https://t.co/u7WjHkhE0k',
#  'Hdpt como le van a hacer eso a una niña, porfavor ayuden a denunciar, es una niña man, como caraj0s le vas a hacer eso, solo tiene 8 años OCHO, aun ais no sea menor de edad es un delito, porfavor compartan y ayuden aunque ya es tarde, intentemos hacer algo https://t.co/ZiNt8Uas5G',
#  'RAPDER CAMPEON MUNDIAL ZORRAS',
#  'azhra pero que guarra eres, me estaba vistiendo, que tenía el pijama aún. https://t.co/4QXgSKpqQS',
#  'El objetivo del diseño fue transformar un espacio histórico oscuro en un ambiente luminoso y cálido que fomente el empoderamiento de las mujeres y establezca una base sólida para el futuro.https://t.co/K0toVRbzSy',
#  'Le mandé esa foto a Flor y no me la está poniendo en fin así son las feministas',
#  '@el_tio_jett q fea tu cuenta borrala https://t.co/GYfNI2v5ps',
#  'El hecho de como su vida inspira a muchas personas por toda constancia que tuvo para lograr sus metas.  Además, ella habla tantos idiomas y se aprende las cosas muy rápido. Literal es tan inteligente y es fácil admirar a una mujer así.',
#  '@AzulAnubis estás tonto o que te pasa. paleto si que eres tú piensa lo que te de la gana pero no insultes ten respeto y digo la verdad no era una ofensa a la mujer es un dicho chaval lo que pasa que si tienes pinta de paleto infórmate mejor anda que no soy el primero que dice ese dicho',
#  '@Quisqueyano56 Jajajajaja....pariguayo optico....tu no eres dominicano ...tu un mierdoso....los que nos sentimos hombres dominicanos de verdad....rechazamos que se siga maltratando a nuestras mujeres domimicanas...NO MAS VIOLENCIA CONTRA NUESTRA MUJERES DOMINICANAS.....',
#  'no le queda una a soldano, la puta madre',
#  '@gomidinosaurio @mbatistarios @Jeancfv03 @TReporta de menores o de mujeres que no tienen suficiente dinero o no están preparadas psicológicamente  para tener un bebe no le veo problema pero ahora si cualquier mujer puede abortar GRATIS lo veo mal ademas de asesinar a un bebe y para colmo para que despues vengan diciendo sigo',
#  '@AveMonarchist @vivicanosaok @AgustinLaje Ok pero ese feminismo no tiene nada que ver con el hembrismo actual, el movimiento actual es totalmente adocttrinado, marxista y socialista.',
#  '@espartaco_II Que le den el puro pescuezo del ganso a doña lili haber si así se consuela ella misma ya que su marido es muy precoz Ho muy pendejo para calmarle las calenturas a doña frígida tellez',
#  '@t0npare @ahijadojj @_ANAMILAN_ Y bañarse desnudo con ellos. Este ejemplar me contó lo contrario, que este humano se dejó sodomizar por todo el  grupo de cetáceos, de ahí el besito de despedida.',
#  'que ha pasao con la chica esa rara de tiktok que no recuerdo como se llama, la rubia tonta que se cree graciosa',
#  '@dalessamauricio ESA Q TOCA EL BOMBO ,ALGUIEN  SE LE ANOMA ,,,,,ES UNA MARIMACHO,X DIOS Q DECADENCIA LA JOBENES .',
#  'En #España no todos los españoles tienen acceso al agua que necesitan, es un problema que exige una respuesta coordinada y firme frente a la división y el enfrentamiento entre territorios que promueve el Gobierno central. El agua es desarrollo, crecimiento, igualdad y justicia. https://t.co/FMFZNtUZPc',
# ...
#  '@Anggrek982 @Bakasta Ya, a mi la idea tras el isekai me encanta, es una oportunidad de empezar de cero y superarte como persona tras lo que no pudiste hacer en la otra vida. Por eso me mata cuando el 95% de las obras reducen la idea a simple fanservice y empoderamiento para adolescentes xD',
#  '#Infografía El gobierno de @CarlosAlvQ es la administración que más ministros de la Presidencia ha tenido.Este lunes se anunció la sustitución de Marcelo Prieto por Geannina Dinarte, quien será la primera mujer en ocupar ese cargo.Más información: https://t.co/Yc6nnnt7RI https://t.co/n4XtdM4MKG',
#  '@elchiringuitotv @RonaldKoeman @SergioRamos Recurrir al manido victimismo no te va a salvar Ronald...',
#  'La @Admon_GobOax promueve la igualdad, el empoderamiento de la mujer y la prevención de la violencia en todos los ámbitos, mediante cursos y talleres dirigidos al personal del @GobOax, brinda herramientas para fortalecer la equidad de género. https://t.co/fGlOA1YBkH https://t.co/8UzRMhSTkz',
#  '¡Escándalo! Filtran #video sexual de Gabriel Soto y piden en redes no compartirlo "Es una violación a mi intimidad", dice el actor https://t.co/ZAGTcuyDT7 https://t.co/CLD6XnX3Jg',
#  '@nereaaramos7 Ya era hora guarra haha',
#  'big mouth hablando de la cultura de la violación es todo lo que necesitan los pibitos que van al secundario',
#  '@geagarcia_ Las mujeres son mas infieles que los hombres.',
#  '¿como? ¿qué? ¿tal es el nivel de desesperación en algunos países, en cada vez más hombres desinteresados por relaciones serias, que llegan a estos extremos? esperad... aún me estoy descojonando de la risa #mgtow https://t.co/BM0MrPWtFP',
#  '@patriot17160449 @Guate_Inmortal_ @AlianzaRgt Helen Mack es la razón por la que no han nombrado las Cortes en Guatemala!. Corrupta y Perversa Marimacho (porque no tiene definición de sexo!) Tiene Coptado el OJ y Min de Gobernación! Ella es parte del Crimen Organizado! DESCARADA',
#  'Ya es hora de que las personas entiendan que hoy en día las mujeres prefieren hacerse cambios físicos para estar bien con ellas mismas que para impresionar a una persona',
#  '@sxrare Ah ah!No en contra de las mujeres, ni en contra de las feministas.En contra de locas que desean el odio mundial a los hombres, que se ofenden hasta de ellas mismas, que no tienen el corazón en los bebés y declaran aborto legal sin dar mucho fundamento.Actualmente estoy en +',
#  'Ella está cansada de ser la chica puente.Es la portadora de la luz. La que sirve de guía. La que aguanta sus quejidos.La que lo sostiene.La que cura sus heridas.La que lo deja nuevo para otra.',
#  '@Faitelson_ESPN En vela quedaste varios días, después de que la fuerza de cuasimodo (LAFC) fuera proyectada en un “ poderoso “ volado de derecha dispuesto a eliminar tus muelas, hace casi 18 años en el Luis Pirata Fuente.',
#  '@sseodeuai Comeback con concepto mujer empoderada vistiendo de blanco pero con anillos de diamantes',
#  '#mgtow @La_Hordaa @EnMgtow @gojiramgtow @Patchito3 @MorfeuTRP  @SigmaKetzal  @EmilHaugen3  @oldesnake  @Donnadie222  @mgtowperseus @necredor  @bibliotecahl @Culeheavy @L0Bo_S0litari0  @JackMgtow y los que quieran mencionar...',
#  'mi mamá siendo una mujer empoderada, humilde y decidida es el real "mejor concepto" https://t.co/SjpmdymwzZ',
#  'Además, al parecer, unir fuerzas entre familiares y amigos para buscar a un ser querido desaparecido, es un delito. Violar, secuestrar y asesinar “es normal”.',
#  '@panaclo Es que. Félix Salgado es de LA ESCORIA DE MORENA y pues hay  IMPUNIDAD',
#  'me comí tremendo trolleo de ariana embarazada la puta',
#  'Ya no quiero ser una zorra',
#  '@akioki0 El chico creyó que podría ser una buena idea ir a aquel edificio de natación, apesar de no estar en ese club tenía curiosidad por saber cómo era por dentro.Al ver a esa chica a lo lejos se acercaría y la miraría confundido, para luego preguntar.— ¿Que pasa?',
#  '@DivididosL6 No se lo merece. Sus respuestas no ayudaron al equipo, bastante trepa',
#  '@manelyk_oficial quiere dejar atrás la imagen que mostró en @AcapulcoShore para convertirse en un ejemplo de empoderamiento femenino https://t.co/CE3SDWZjwt https://t.co/gCL7YDtnGX',
#  'A mi yo del 2021 le pido que deje de ser una puta payasa',
#  'Leyendo a @LaMalaC veo que el feminismo de @MovCiudadanoMX está igual que el de MORENA: mucho discurso pero en los hechos que no incomode a los machos de arriba.',
#  '#VolveriasConTuExMega "una parte del pueblo chileno te ve como mosca muerta y mojigata" "el supuesto pueblo chileno" = la aylen y la oriana.',
#  '@1horaenlibertad @RadioYa_es @Javiergaciaisac @rebecacrespo_ Escuchando #EnlaBocadelLobo @RadioYa_es , con el genuino @Javiergaciaisac y #MíticaRebeca @rebecacrespo_ y que risa por favor. Entre la chirimoya, la prueba del cerebelo y los rincones ocultos de la nenaza, es q me meo. Actualidad con rigor y toques de humor, buenísimo,',
#  'Te acompaño a denunciarlo, me ha hecho lo mismo, #MeToo https://t.co/vAsu2WRxq6',
#  'Alexa, define #cowardice. #DavidAlanHarvey #Coward #BelieveWomen #IBelieveWomen #Magnum #MeToo https://t.co/WLTtIDldZX',
#  '@PatoFdez Pareciera que los egos pueden más que la realidad. Sobran Caudillos y no se vislumbra ni un solo Líder! Ojalá aparezca un/a Angela Merkel o Jacinda Arden...parece que las mujeres se deben mostrar más!',
#  '@forocoches Mi abuelo decía: mujer al volante, peligro constante. Que sabio eras abuelo y que palizas nos metías',
#  'Apostado frente al aparcamiento del hospital con el Citröen Saxo de su mujer, vio salir tres tardes seguidas el todoterreno negro con el Dr. Gomariz al volante y solo; el cuarto día, 24 de enero, el médico salió del aparcamiento con una mujer en el asiento del copiloto.',
#  'Hoy mando a comer mlerda a todita la organización feminazi #metoo. No son más que unos malditos hijos de la gran pxta marxistas que le valen un carajo las mujeres y utilizan su eslogan para acusar falsamente a todo aquel que ellos consideren adversario ideológico de la izquierda',
#  '@praise_kenki Historia es realmente el ejemplo de una mujer empoderada, no es necesaria la fuerza si tiene un mente débil. Historia es realmente buena en todo los aspectos y lo más importante, es una mujer LIBRE y en todo su esplendor ella es la verdadera mujer EMPODERADA.',
#  '@Jbetiquetanegra por lo tanto..es violación de propiedad privada',
#  'TOP MOMENTOS 2020: Después de 20 años, regresa a la televisión abierta "Betty, la fea".El comeback del año no podía ser para nadie más que para "Betty, la fea" que a pesar de haberse estrenado hace más de 20 años, volvió transmitirse por Azteca 7 con todo el éxito. https://t.co/N8OIDLFOAU',
#  'Ciudadanos ha llegado a un pacto con un partido xenófobo y fascista.Ha acordado estos presupuestos con quienes dicen cosas como que "un extranjero es 3 veces más propenso a violar que un español". Que no te cuenten películas. https://t.co/eHbHHgAuL9',
#  '@asmixwalls La chica',
#  'Pertenezco al 0.1 % de los hombres a los que nos gustan las mujeres asi.  https://t.co/HALxA5eYRz',
#  '@doppominx Mí letra es tan fea que mí profesora de Físico Química me preguntó si quería estudiar medicina https://t.co/XpVcRshyo5',
#  '@candelalozana1 y no me invitaste a estar en culo con vos',
#  '@rexhabots Merece*',
#  '@ItsCarlituss @KembaGRV @Recuerd0p se nota la gente humilde y la gente con ego q lo q hacen es tocar la polla literalmente',
#  'el comentario de abajo del comentario de la chica q tiene covid quedó  https://t.co/wE3iKeqzmR',
#  'Amo Smash porque le puedo pegar a las mujeres',
#  '@CoronelHMejia Mi Coronel. Para sumerced y todos los suyos una Feliz Navidad, mucha salud y prosperidad infinita. Dios Todopoderoso sabe que Ud es un buen hombre, lo que tanto necesita nuestra patria.',
#  'Me entristece ver que el ser humano sea capaz de semejante salvajada.Hubo un tiempo,hace miles de años en que el hombre cazaba por necesidad.Pero ahora  no entiendo lo de exterminar animales  en masa.Sencillo la Naturaleza necesita al hombre o es al revés: https://t.co/ThvKjdEwhr https://t.co/12NbBpiC7S',
#  'Jaja no os pasa q a partir de los 20 años y 546 días os convertís en el puto joker???  Da que pensar  #MeToo',
#  "@gorez1 Pues en el momento en que el KK's @lopezobrador_ comenzó a sodomizar al pueblo con su politiquería mentirosa.",
#  '@ViggianoMila Y si, como no vas a tener miedo si se te viene un hombre encima además ante un hecho de violencia de género tienen que actuar, no van a dejar que el violento ataque.Hay gente tan desagradecida.Vos has actuado bien, cuando pudiste los ayudaste!!',
#  '@chriscriskriz @ConejoSaurioRex @libertad_surja Dentro de los primeros meses es completamente aceptable porque la mujer es libre de decidir sobre su cuerpo y su vida, ya cuando tienen 7 u 8 meses de gestación ni siquiera hablaríamos de un aborto sino de un parto inducido.',
#  '@Mermaidkuromi @marialy_rivas @Plasticview @LuisLarrain Si, el rechazo puede hacer mucho daño al hombre, sobretodo en edades tempranas, cuando la mayoría aún creemos que ustedes las mujeres son capaces de sentir amor.',
#  'En serio, ¿alguien cree que el tema de la pirotecnia tiene que ver con ser "políticamente correctos"?Afecta a los niños con autismo, personas con sensibilidad auditiva y a los animales.Diviértanse sin fregar al resto. Un rato basta, no creen? #NoALaPirotecnia',
#  '@Arpia13 @alethb11 Híjoles, esta foto es una violación a mi intimidad.',
#  'Pero que cosa fea los caramelos filmpaff',
#  '@FridaSiKahlo Mochilera si Tu fea JAMAS !!!',
#  'Ay Jorge Jorge que se quedó como primer finalista de milagro, que si el público en vez del 10 le llega a dar un 7 o un 6 se queda fuera y pasaba primera Cristina que es lo que merece #TCMS15',
#  'Así veo sus fotos en tetas de ayer mientras yo tuve que vestirme de reno y taparme porque hacen 2° https://t.co/GXJmyzCWI3',
#  '@FeetLoira Quiero lamerte las tetas apretarlas y chupar tus pezones duros mientras te masturbo el coñito hasta correrte mmmm',
#  'LO MEJOR Y LO MÁS LEÍDO DEL 2020 El nacimiento de otra nación#9M2020: Un día sin mujeres, por @VekaDuncan https://t.co/geBmJfyFOC https://t.co/g5LVPXPoPt',
#  '@HectorRC_AO @Roberto_Politik @tumbaburross Pobre prensa reprimida jajajaja https://t.co/oeWUziy6DN',
#  '@JorgeIvanOspina Alcalde a ver ustedes pueden reunir 1000 personas en un lugar cerrado y no pasa nada , y ahora las personas no van a poder salir ,coje oficio hombre y deja de estar diciendo tanta pendejada, ya las personas tienen vacaciones listas y el sistema hotelero las necesita.',
#  '@BaezJaelp @DeluxeSabado Esta Sra d ganas d cagar jjjjjj k asco d tia k se vaya con el gorrino coletas ,solo verle la boca tiene una pinta d guarra',
#  '"la emborrachamos y que se la cojan"... Que según yo tengo entendido es violación.¡¡¡Y sus programas tienen más de 10 mil vistas en un Estado que lidera a nivel nacional denuncias por violación sexual!!! Esto no esta bien por donde quieran que lo miren.',
#  '@WxtchingYou Más bien lo que yo te pida.—estrecha el cuerpo impropio, comenzando a llenar su mejilla de pequeños besos. Realmente quiere saber cómo se siente actuar de aquella forma—.',
#  '@claudia_cobo Tú nunca estás fea',
#  'me escribió una chica por ig, tons le pregunto que si nos conocemos, me responde que si, por wattpad lpm',
#  'Pero vaya puta barbaridad de capítulo 1000 vaya cojonazos que tiene Luffy loco qué hablas hacía un poco de tiempo que no me hypeaba con One Piece así',
#  '@SanGomezLopez @abc_es “Frente a una visión mojigata, prefiero poner en valor...” Usted lo único que pone en valor es evidenciar su ignorancia. ¿Ha leído usted a Ratzinger, por no irme mucho más atrás en el tiempo, para entender la Mariología católica y comprender la importancia que se le da a María.',
#  'Cuídense soldados.Así son todas las mujeres de hoy en día y sin excepciones.#NiUnoMenos @Vynylplayer https://t.co/vgOkkDKI5r',
#  '@Danielitao_0 @MaxPowxr1972 Que se haga sodomizar ese boludo!',
#  '@SchrodingerGata @YouTubeEspanol Existe el libre albedrío... que lo ejercen los pensantes.Consuela saber que un hombre de verdad no necesita de semejante imbecilidad... no se rebajaría voluntariamente a un adoctrinamiento para deficientes mentales.De seguro que el IQ de todos los participantes, no lega a 50.',
#  '@m_ebrard Es importante la participación de las mujeres en la política mexicana. Cuando se vuelve irrelevante es cuando ponen a gente incompetente, como todos los de la 4T. Corruptas como Irma Eréndira, Roció Nahle, Citlalli Hernández, Felipa Obrador o Ana Guevara no deberían presumirse.',
#  '@Viri_Rios Cuanto complejo en estas palabras, que mente tan estrecha tienen los morenistas, imposible debatir.',
#  '@E_Gorria @elpais_toros Quizá tengas la mente estrecha...',
#  ...]

# %%
len(tuits)
# Out:
# 3541

# %%
tokens_texto = []

for tuit in tuits:
  doc = nlp(tuit)
  for token in doc:
    tokens_texto.append(token.text)

# %%
tokens_texto

# %%
len(tokens_texto)

# %%
partes_del_discurso = []
explicacion = []

for tuit in tuits:
  doc = nlp(tuit)
  for token in doc:
    partes_del_discurso.append(token.pos_)
    explicacion.append(token.tag_)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/autocast_mode.py:162: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')

# %%
len(partes_del_discurso)
# Out:
# 115635

# %%
from collections import Counter

contador_partes_del_discurso = Counter(partes_del_discurso)
contador_partes_del_discurso.most_common(10)
# Out:
# [('NOUN', 18380),
#  ('VERB', 13296),
#  ('DET', 12383),
#  ('ADP', 12301),
#  ('PUNCT', 11416),
#  ('PROPN', 10917),
#  ('PRON', 9186),
#  ('ADJ', 6484),
#  ('ADV', 6159),
#  ('AUX', 5412)]

# %%
etiquetas_dependencias_gramaticales = []
explicacion_dependencias = []

for tuit in tuits:
  doc = nlp(tuit)
  for token in doc:
    etiquetas_dependencias_gramaticales.append(token.dep_)
    explicacion_dependencias.append(spacy.explain(token.dep_))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/autocast_mode.py:162: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# /usr/local/lib/python3.7/dist-packages/spacy/glossary.py:19: UserWarning: [W118] Term 'ROOT' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# /usr/local/lib/python3.7/dist-packages/spacy/glossary.py:19: UserWarning: [W118] Term 'expl:pv' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# /usr/local/lib/python3.7/dist-packages/spacy/glossary.py:19: UserWarning: [W118] Term 'expl:pass' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# /usr/local/lib/python3.7/dist-packages/spacy/glossary.py:19: UserWarning: [W118] Term 'expl:impers' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))

# %%
etiquetas_dependencias_gramaticales
# Out:
# ['nsubj',
#  'obj',
#  'aux',
#  'mark',
#  'ROOT',
#  'advmod',
#  'advmod',
#  'mark',
#  'det',
#  'obl',
#  'nsubj',
#  'iobj',
#  'obj',
#  'acl',
#  'xcomp',
#  'case',
#  'amod',
#  'obl',
#  'punct',
#  'nmod',
#  'mark',
#  'amod',
#  'ROOT',
#  'amod',
#  'punct',
#  'amod',
#  'det',
#  'nsubj',
#  'mark',
#  'acl',
#  'det',
#  'obj',
#  'mark',
#  'nmod',
#  'punct',
#  'obj',
#  'ROOT',
#  'nsubj',
#  'obj',
#  'ROOT',
#  'case',
#  'det',
#  'nummod',
#  'obl',
#  'case',
#  'det',
#  'obl',
#  'amod',
#  'case',
#  'nmod',
#  'cc',
#  'advmod',
#  'conj',
#  'advmod',
#  'obj',
#  'advcl',
#  'mark',
#  'mark',
#  'nmod',
#  'obj',
#  'det',
#  'nsubj',
#  'obj',
#  'acl',
#  'cop',
#  'ROOT',
#  'mark',
#  'mark',
#  'nsubj',
#  'flat',
#  'cop',
#  'det',
#  'acl',
#  'amod',
#  'punct',
#  'advmod',
#  'advcl',
#  'det',
#  'obj',
#  'punct',
#  'obl',
#  'advmod',
#  'case',
#  'det',
#  'obj',
#  'obj',
#  'ROOT',
#  'mark',
#  'mark',
#  'obj',
#  'advcl',
#  'punct',
#  'mark',
#  'fixed',
#  'iobj',
#  'iobj',
#  'advcl',
#  'punct',
#  'obj',
#  'advmod',
#  'cc',
#  'conj',
#  'punct',
#  'det',
#  'obl',
#  'advmod',
#  'aux',
#  'ROOT',
#  'det',
#  'obj',
#  'amod',
#  'punct',
#  'amod',
#  'punct',
#  'mark',
#  'iobj',
#  'parataxis',
#  'punct',
#  'case',
#  'det',
#  'nmod',
#  'nsubj',
#  'acl',
#  'det',
#  'obj',
#  'advmod',
#  'amod',
#  'cc',
#  'det',
#  'conj',
#  'mark',
#  'nmod',
#  'punct',
#  'advmod',
#  'det',
#  'obj',
#  'obj',
#  'ROOT',
#  'obj',
#  'mark',
#  'mark',
#  'mark',
#  'expl:pv',
#  'advcl',
#  'case',
#  'obj',
#  'ROOT',
#  'appos',
#  'punct',
#  'csubj',
#  'case',
#  'obj',
#  'advmod',
#  'aux',
#  'cop',
#  'det',
#  'ROOT',
#  'case',
#  'obj',
#  'punct',
#  'det',
#  'ROOT',
#  'case',
#  'nmod',
#  'cc',
#  'conj',
#  'punct',
#  'appos',
#  'punct',
#  'ROOT',
#  'advmod',
#  'obj',
#  'case',
#  'obj',
#  'mark',
#  'obj',
#  'mark',
#  'advcl',
#  'xcomp',
#  'case',
#  'obj',
#  'amod',
#  'punct',
#  'det',
#  'nsubj',
#  'flat',
#  'flat',
#  'cc',
#  'conj',
#  'flat',
#  'advmod',
#  'case',
#  'det',
#  'obl',
#  'det',
#  'nsubj',
#  'advmod',
#  'csubj',
#  'nsubj',
#  'advmod',
#  'advcl',
#  'advmod',
#  'advcl',
#  'nsubj',
#  'case',
#  'det',
#  'obl',
#  'nummod',
#  'case',
#  'det',
#  'obl',
#  'appos',
#  'cop',
#  'advmod',
#  'advcl',
#  'ROOT',
#  'cc',
#  'conj',
#  'det',
#  'obj',
#  'amod',
#  'cc',
#  'conj',
#  'obl',
#  'obj',
#  'ROOT',
#  'flat',
#  'ROOT',
#  'xcomp',
#  'punct',
#  'advmod',
#  'iobj',
#  'advcl',
#  'det',
#  'obj',
#  'appos',
#  'advmod',
#  'advmod',
#  'fixed',
#  'aux',
#  'ROOT',
#  'obj',
#  'case',
#  'det',
#  'obl',
#  'case',
#  'nmod',
#  'punct',
#  'case',
#  'fixed',
#  'punct',
#  'cop',
#  'advcl',
#  'case',
#  'det',
#  'nmod',
#  'case',
#  'nmod',
#  'mark',
#  'nmod',
#  'obj',
#  'advcl',
#  'case',
#  'obj',
#  'cc',
#  'mark',
#  'nsubj',
#  'obj',
#  'conj',
#  'punct',
#  'mark',
#  'fixed',
#  'advmod',
#  'mark',
#  'advcl',
#  'mark',
#  'nsubj',
#  'advmod',
#  'ccomp',
#  'case',
#  'obj',
#  'det',
#  'nsubj',
#  'punct',
#  'advcl',
#  'mark',
#  'ROOT',
#  'cop',
#  'det',
#  'nsubj',
#  'punct',
#  'csubj',
#  'obj',
#  'advmod',
#  'fixed',
#  'cop',
#  'ROOT',
#  'punct',
#  'cop',
#  'advmod',
#  'advcl',
#  'punct',
#  'cop',
#  'ROOT',
#  'case',
#  'det',
#  'nmod',
#  'nsubj',
#  'acl',
#  'case',
#  'det',
#  'det',
#  'obj',
#  'case',
#  'det',
#  'nmod',
#  'case',
#  'det',
#  'obj',
#  'punct',
#  'ROOT',
#  'case',
#  'nmod',
#  'det',
#  'ROOT',
#  'obj',
#  'obj',
#  'acl',
#  'advmod',
#  'expl:pass',
#  'iobj',
#  'aux',
#  'mark',
#  'acl',
#  'obj',
#  'amod',
#  'case',
#  'obl',
#  'mark',
#  'acl',
#  'mark',
#  'advcl',
#  'nsubj',
#  'iobj',
#  'ROOT',
#  'advmod',
#  'xcomp',
#  'cc',
#  'conj',
#  'punct',
#  'mark',
#  'advcl',
#  'det',
#  'obj',
#  'mark',
#  'advcl',
#  'punct',
#  'advcl',
#  'cc',
#  'advmod',
#  'conj',
#  'case',
#  'advmod',
#  'mark',
#  'advcl',
#  'obj',
#  'amod',
#  'mark',
#  'ROOT',
#  'advmod',
#  'compound',
#  'det',
#  'det',
#  'obj',
#  'case',
#  'det',
#  'nmod',
#  'case',
#  'det',
#  'nmod',
#  'amod',
#  'punct',
#  'ROOT',
#  'mark',
#  'nsubj',
#  'advcl',
#  'mark',
#  'aux',
#  'xcomp',
#  'punct',
#  'nsubj',
#  'obj',
#  'ROOT',
#  'case',
#  'det',
#  'obj',
#  'amod',
#  'punct',
#  'nsubj',
#  'case',
#  'det',
#  'flat',
#  'cop',
#  'ROOT',
#  'nummod',
#  'obl',
#  'mark',
#  'advcl',
#  'det',
#  'obj',
#  'case',
#  'nmod',
#  'amod',
#  'punct',
#  'ROOT',
#  'nmod',
#  'amod',
#  'punct',
#  'appos',
#  'punct',
#  'nmod',
#  'punct',
#  'appos',
#  'nmod',
#  'appos',
#  'nmod',
#  'cop',
#  'ROOT',
#  'cc',
#  'conj',
#  'det',
#  'obj',
#  'cop',
#  'csubj',
#  'mark',
#  'acl',
#  'det',
#  'nsubj',
#  'mark',
#  'advcl',
#  'case',
#  'nummod',
#  'obj',
#  'punct',
#  'amod',
#  'csubj',
#  'punct',
#  'ROOT',
#  'flat',
#  'det',
#  'nsubj',
#  'cop',
#  'ROOT',
#  'punct',
#  'advcl',
#  'det',
#  'obj',
#  'nsubj',
#  'acl',
#  'xcomp',
#  'case',
#  'det',
#  'obj',
#  'punct',
#  'ROOT',
#  'det',
#  'obj',
#  'case',
#  'det',
#  'nmod',
#  'nsubj',
#  'acl',
#  'xcomp',
#  'case',
#  'det',
#  'obj',
#  'punct',
#  'cc',
#  'case',
#  'obl',
#  'cc',
#  'conj',
#  'conj',
#  'cc',
#  'conj',
#  'case',
#  'det',
#  'det',
#  'obj',
#  'punct',
#  'ROOT',
#  'cc',
#  'conj',
#  'case',
#  'det',
#  'obj',
#  'cc',
#  'case',
#  'det',
#  'conj',
#  'amod',
#  'case',
#  'nmod',
#  'punct',
#  'ROOT',
#  'det',
#  'obj',
#  'case',
#  'nmod',
#  'det',
#  'appos',
#  'ROOT',
#  'flat',
#  'punct',
#  'det',
#  'det',
#  'nmod',
#  'punct',
#  'obj',
#  'ROOT',
#  'det',
#  'nsubj',
#  'acl',
#  'case',
#  'obl',
#  'amod',
#  'nsubj',
#  'acl',
#  'obj',
#  'cc',
#  'conj',
#  'punct',
#  'det',
#  'nsubj',
#  'expl:pv',
#  'ROOT',
#  'punct',
#  'ROOT',
#  'ROOT',
#  'dep',
#  'ROOT',
#  'mark',
#  'ROOT',
#  'cop',
#  'det',
#  'amod',
#  'nsubj',
#  'appos',
#  'iobj',
#  'ROOT',
#  'xcomp',
#  'mark',
#  'advmod',
#  'case',
#  'det',
#  'amod',
#  'obl',
#  'csubj',
#  'case',
#  'det',
#  'obj',
#  'punct',
#  'advcl',
#  'punct',
#  'advmod',
#  'advcl',
#  'mark',
#  'cop',
#  'ccomp',
#  'amod',
#  'nsubj',
#  'advmod',
#  'acl',
#  'obj',
#  'amod',
#  'punct',
#  'cc',
#  'conj',
#  'mark',
#  'cop',
#  'det',
#  'ccomp',
#  'punct',
#  'ROOT',
#  'det',
#  'obj',
#  'advmod',
#  'det',
#  'advmod',
#  'appos',
#  'punct',
#  'nsubj',
#  'flat',
#  'cop',
#  'det',
#  'ROOT',
#  'ccomp',
#  'mark',
#  'xcomp',
#  'det',
#  'obj',
#  'mark',
#  'nmod',
#  'punct',
#  'nsubj',
#  'ROOT',
#  'xcomp',
#  'det',
#  'obj',
#  'cc',
#  'mark',
#  'iobj',
#  'advcl',
#  'dep',
#  'fixed',
#  'ccomp',
#  'ccomp',
#  'case',
#  'det',
#  'obl',
#  'amod',
#  'case',
#  'nmod',
#  'case',
#  'nmod',
#  'cc',
#  'det',
#  'conj',
#  'case',
#  'det',
#  'nmod',
#  'iobj',
#  'conj',
#  'ccomp',
#  'mark',
#  'det',
#  'nsubj',
#  'cop',
#  'ccomp',
#  'case',
#  'nmod',
#  'cc',
#  'fixed',
#  'mark',
#  'advmod',
#  'conj',
#  'obj',
#  'cc',
#  'conj',
#  'amod',
#  'case',
#  'nmod',
#  'dep',
#  'cc',
#  'advmod',
#  'case',
#  'obl',
#  'conj',
#  'nsubj',
#  'flat',
#  'flat',
#  'flat',
#  'flat',
#  'flat',
#  'flat',
#  'flat',
#  'flat',
#  'flat',
#  'flat',
#  'flat',
#  'flat',
#  'obl',
#  'aux',
#  'mark',
#  'ROOT',
#  'mark',
#  'advmod',
#  'cop',
#  'ccomp',
#  'case',
#  'punct',
#  'det',
#  'nsubj',
#  'case',
#  'nmod',
#  'advmod',
#  'ccomp',
#  'punct',
#  'nsubj',
#  'ROOT',
#  'obj',
#  'mark',
#  'acl',
#  'mark',
#  'xcomp',
#  'punct',
#  'mark',
#  'conj',
#  'punct',
#  'mark',
#  'conj',
#  'obj',
#  'punct',
#  'mark',
#  'obl',
#  'ROOT',
#  'mark',
#  'case',
#  'det',
#  'dep',
#  'ccomp',
#  'cc',
#  'conj',
#  'case',
#  'obl',
#  'punct',
#  'cc',
#  'case',
#  'det',
#  'conj',
#  'obl',
#  'nsubj',
#  'acl',
#  'mark',
#  'obj',
#  'ccomp',
#  'punct',
#  'case',
#  'obl',
#  'dep',
#  'punct',
#  'case',
#  'obl',
#  'mark',
#  'dep',
#  'ROOT',
#  'case',
#  'det',
#  'obj',
#  'dep',
#  'flat',
#  'iobj',
#  'advcl',
#  'obj',
#  'advcl',
#  'obj',
#  'ROOT',
#  'flat',
#  'punct',
#  'flat',
#  'flat',
#  'punct',
#  'appos',
#  'punct',
#  'flat',
#  'punct',
#  'cop',
#  'advcl',
#  'appos',
#  'punct',
#  'nsubj',
#  'advcl',
#  'punct',
#  'ROOT',
#  'punct',
#  'case',
#  'det',
#  'nmod',
#  'ROOT',
#  'flat',
#  'flat',
#  'punct',
#  'flat',
#  'flat',
#  'cc',
#  'advmod',
#  'iobj',
#  'ROOT',
#  'mark',
#  'det',
#  'det',
#  'nsubj',
#  'iobj',
#  'ccomp',
#  'case',
#  'obj',
#  'mark',
#  'acl',
#  'case',
#  'det',
#  'obj',
#  'mark',
#  'iobj',
#  'advcl',
#  'obj',
#  'mark',
#  'cop',
#  'advcl',
#  'ROOT',
#  'det',
#  'nsubj',
#  'advmod',
#  'expl:pass',
#  'ROOT',
#  'punct',
#  'advmod',
#  'expl:pass',
#  'advcl',
#  'punct',
#  'advmod',
#  'expl:pv',
#  'advcl',
#  'punct',
#  'mark',
#  'ROOT',
#  'det',
#  'obj',
#  'cc',
#  'conj',
#  'case',
#  'amod',
#  'obj',
#  'mark',
#  'advcl',
#  'ROOT',
#  'appos',
#  'flat',
#  'flat',
#  'punct',
#  'flat',
#  'punct',
#  'flat',
#  'appos',
#  'ROOT',
#  'flat',
#  'amod',
#  'ROOT',
#  'amod',
#  'case',
#  'nmod',
#  'appos',
#  'acl',
#  'case',
#  'det',
#  'obj',
#  'punct',
#  'det',
#  'appos',
#  'amod',
#  'cc',
#  'case',
#  'conj',
#  'punct',
#  'mark',
#  'det',
#  'nsubj',
#  'case',
#  'nmod',
#  'advmod',
#  'cop',
#  'det',
#  'ccomp',
#  'amod',
#  'punct',
#  'ROOT',
#  'punct',
#  'acl',
#  'mark',
#  'advcl',
#  'advmod',
#  'nummod',
#  'obj',
#  'punct',
#  'cc',
#  'conj',
#  'punct',
#  'advmod',
#  'advcl',
#  'det',
#  'amod',
#  'obj',
#  'punct',
#  'punct',
#  'ROOT',
#  'flat',
#  'appos',
#  'punct',
#  'appos',
#  'appos',
#  'ROOT',
#  'flat',
#  'flat',
#  'cc',
#  'det',
#  'conj',
#  'advcl',
#  'mark',
#  'fixed',
#  'fixed',
#  'fixed',
#  'expl:pass',
#  'obj',
#  'advcl',
#  'nsubj',
#  'ROOT',
#  'advmod',
#  'advmod',
#  'expl:pv',
#  'ROOT',
#  'mark',
#  'cop',
#  'det',
#  'advcl',
#  'case',
#  'det',
#  'nmod',
#  'punct',
#  'mark',
#  'nsubj',
#  'cc',
#  'conj',
#  'cop',
#  'det',
#  'advmod',
#  'amod',
#  'advcl',
#  'punct',
#  'obj',
#  'cc',
#  'conj',
#  'punct',
#  'ROOT',
#  'advmod',
#  'det',
#  'nsubj',
#  'nsubj',
#  'expl:pass',
#  'acl',
#  'punct',
#  'case',
#  'det',
#  'amod',
#  'obl',
#  'punct',
#  'nsubj',
#  'aux',
#  'cop',
#  'ROOT',
#  'case',
#  'obj',
#  'case',
#  'det',
#  'nmod',
#  'case',
#  'nmod',
#  'case',
#  'nmod',
#  'case',
#  'advmod',
#  'nmod',
#  'case',
#  'det',
#  'nmod',
#  'punct',
#  'acl',
#  'det',
#  'obj',
#  'case',
#  'nummod',
#  'nmod',
#  'punct',
#  'cc',
#  'conj',
#  'case',
#  'nummod',
#  'punct',
#  'ROOT',
#  'ROOT',
#  'flat',
#  'obl',
#  'iobj',
#  'flat',
#  'iobj',
#  'acl',
#  'obl',
#  'cop',
#  'advmod',
#  'ccomp',
#  'punct',
#  'case',
#  'ROOT',
#  'punct',
#  'appos',
#  'amod',
#  'punct',
#  'punct',
#  'flat',
#  'flat',
#  'amod',
#  'punct',
#  ...]

# %%
contador_etiquetas_dependencias_gramaticales  = Counter(etiquetas_dependencias_gramaticales )
contador_etiquetas_dependencias_gramaticales.most_common(10)
# Out:
# [('det', 12859),
#  ('punct', 11858),
#  ('case', 9683),
#  ('obj', 9008),
#  ('ROOT', 7518),
#  ('advmod', 6588),
#  ('nsubj', 6510),
#  ('mark', 6084),
#  ('nmod', 4363),
#  ('advcl', 4201)]

# %%
tokens_con_alfanumericos = []

for tuit in tuits:
  doc = nlp(tuit)
  for token in doc:
    tokens_con_alfanumericos.append(token.is_alpha)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/autocast_mode.py:162: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')

# %%
contador_tokens_con_alfanumericos  = Counter(tokens_con_alfanumericos)
contador_tokens_con_alfanumericos.most_common(10)
# Out:
# [(True, 96543), (False, 19092)]

# %%
tokens_con_minusculas = []

for tuit in tuits:
  doc = nlp(tuit)
  for token in doc:
    tokens_con_minusculas.append(token.is_lower)

# %%
contador_tokens_con_minusculas  = Counter(tokens_con_minusculas)
contador_tokens_con_minusculas.most_common(10)

# %%
tokens_con_mayusculas = []

for tuit in tuits:
  doc = nlp(tuit)
  for token in doc:
    tokens_con_mayusculas.append(token.is_upper)

# %%
contador_tokens_con_mayusculas  = Counter(tokens_con_mayusculas)
contador_tokens_con_mayusculas.most_common(10)

# %%
tokens_de_signos_de_puntuacion = []

for tuit in tuits:
  doc = nlp(tuit)
  for token in doc:
    tokens_de_signos_de_puntuacion.append(token.is_punct)

# %%
contador_tokens_de_signos_de_puntuacion = Counter(tokens_de_signos_de_puntuacion)
contador_tokens_de_signos_de_puntuacion.most_common(10)

# %%
lemmas = []

for tuit in tuits:
  doc = nlp(tuit)
  for token in doc:
    lemmas.append(token.lemma_)

# %%
lemmas

# %% [markdown]
# # Siguiente paso: Obtener sólo ciertas POS
#
# Anteriormente hemos:
#
# 1. Cargado un modelo de español de spaCy.
# 2. Cargado un conjunto de datos usando pandas.
# 3. Hecho limpieza de los datos (eliminación de ciertas columnas, eliminación de tuits marcados como 'en', etc.)
# 4. Procesado los datos usando el modelo de español precargado.
# 5. Extraído las tokens, POS, dependencias sintácticas, tokens alfanuméricos, etc. de nuestros datos.
#
# Ahora, usando la información del paso 5, extraeremos **sólo** ciertas POS que nos interesen. Antes extraímos todas las POS de nuestros datos, pero a veces no queremos eso.
#
# Para obtener sólo las POS que nos interesen, debemos incluir un ciclo `if` que coondicione la extracción a lo que queramos.

# %% [markdown]
# ![Screen Shot 2022-05-02 at 12.11.16.png](data:image/png;base64,...)

# %% [markdown]
# Ejemplo: Extraeremos sólo los tokens POS que concuerden con la etiqueta `ADJ`.
#
# Lo que pasará es que, de todas las POS, guardaremos sólo las tokens cuya POS sea igual a `ADJ`. O sea, obtendremos sólo los tokens que spaCy haya etiquetado como adjetivos.
#
# Recordemos que la lista `partes_del_discurso` generada anteriormente ya contiene todas las POS de nuestros datos. Crearemos una lista idéntica, pero le agregaremos los `tokens.text`, pues anteriormente sólo guardamos los `token.pos_` con el fin de no sólo obtener todas las etiquetas sino los tokens a los cuales les correspondan esas etiquetas.

# %%
# esta lista contendrá sólo los tokens que hayan sido etiquetados como "ADJ".
tokens_adjetivos = []

for tuit in tuits:
  doc = nlp(tuit)
  for token in doc:
    if token.pos_ == 'ADJ':
      tokens_adjetivos.append(token.text)

# %% [markdown]
# A continuación repetiremos lo mismo pero para obtener solo los `token.text` cuyo `token.pos_` sea `VERB`.

# %%
# esta lista contendrá sólo los tokens que hayan sido etiquetados como "ADJ".
tokens_verbos = []

for tuit in tuits:
  doc = nlp(tuit)
  for token in doc:
    if token.pos_ == 'VERB':
      tokens_verbos.append(token.text)

# %% [markdown]
# Ahora escribiremos una **función** que tome dos parámetros:
# 1. Una lista (en este caso la hemos nombrado `tuits`) que contenga strings.
# 2. Un string `POS` que indique el tipo de `token.text` que deseemos obtener.
#
# La función nos devolverá una lista con los `token.text` que hayamos indicado en el parámetro.
#
# Esta es una ventaja de usar objetos en Python; estos nos permiten reutilizar nuesto código.

# %%
def obtiene_pos(tuits, parametro):
  # esta lista contendrá sólo los tokens que hayan sido etiquetados como "parametro".
  tokens_finales = []
  for tuit in tuits:
    doc = nlp(tuit)
    for token in doc:
      # str(parametro) toma al parámetro `parametro` de entrada, y lo usa para 
      # ponerle la condición de extracción a python. si el usuario de la función
      # pone parámetro='ADJ', la línea 11 será token.pos_ == 'ADJ'.
      if token.pos_ == str(parametro):
        tokens_finales.append(token.text)
  # es importante siempre poner un return seguido de lo que queramos que nuestra
  # función nos devuelva al final de su ejecución.
  return tokens_finales

# %% [markdown]
# Probemos nuestra función, guardando nuestros resultados en una nueva variable.

# %%
tokens_adv = obtiene_pos(tuits, 'ADV')

# %%
print(tokens_adv)

# %% [markdown]
# Podemos reutilizar la función anterior para obtener todos los `token.text` que deseemos de cualquier lista.
